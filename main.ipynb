# %%
import rsam_ew

# %%
rsam_file = 'RSAM 10Minutes 0104-0105.zip'

# %%
rsam = rsam_ew.RsamEW(rsam_file,
                      station='PCKD',
                      channel='EHZ',
                      wildcard='.DAT', 
                      combine_data=False)

# %%
df = rsam.plot('2024-04-01', '2024-05-02', height=6, y_max=400)
# Out:
# ⚠️ Skip. File not found: D:\Projects\rsam-ew\output\extracted\VG.PCKD.00.EHZ\2024-05-02.csv
# ✅ RSAM file saved at D:\Projects\rsam-ew\output\rsam\VG.PCKD.00.EHZ\rsam_2024-04-01_2024-05-02.csv
# 📈 RSAM Graphics saved to D:\Projects\rsam-ew\figures\rsam_VG.PCKD.00.EHZ_2024-04-01_2024-05-02_1d.png
